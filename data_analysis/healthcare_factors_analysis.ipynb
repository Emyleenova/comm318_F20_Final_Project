# %% [markdown]
# ### healthcare_factors_analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
od_cov= pd.read_csv('../data/data_clean/change_OD_2019_to_2020.csv')
trends_df = pd.read_csv('../data/data_clean/trends.csv')
hc_df = pd.read_csv('../data/data_clean/healthcare_factors.csv')

# %%
hc_df
# Out:
#              STATE POSTCODE  TLHLAUD  TLHLMED  TLHlBUPR  EXTOPFL  HMDLVOP  \
# 0          Alabama       AL        1        1         0        0        0
# 1           Alaska       AK        1        1         0        0        0
# 2          Arizona       AZ        1        1         0        0        0
# 3         Arkansas       AR        1        1         0        0        0
# 4       California       CA        1        1         0        0        0
# 5         Colorado       CO        1        1         0        0        0
# 6      Connecticut       CT        1        1         0        0        0
# 7         Delaware       DE        1        1         0        0        0
# 8          Florida       FL        0        1         0        0        0
# 9          Georgia       GA        1        1         0        0        0
# 10          Hawaii       HI        1        1         0        0        0
# 11           Idaho       ID        1        1         0        0        0
# ...

# %% [markdown]
#  I don't think there is enough difference between states to really get a good picture
