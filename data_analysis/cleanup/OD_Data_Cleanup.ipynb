# %% [markdown]
# # OD Data Cleanup
# * In this notebook, I will clean/organize the raw CDC data so that it is organized by state and month

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
od_df = pd.read_csv('../data/data_raw/us_overdose_data.csv')

# %% [markdown]
# ### Initial data exploration
# Steps
# * Load in dataframe
# * How many rows/columns are there?
# * Define column labels with meta data
# * What does each row represent?
# * Is there missing data?

# %%
od_df.shape
od_nrows = od_df.shape[0]
od_ncols = od_df.shape[1]
print(f'There are {od_nrows} rows and {od_ncols} columns in the Overdose data frame')
# Out:
# There are 35490 rows and 12 columns in the Overdose data frame

# %%
od_df.columns
# Out:
# Index(['State', 'Year', 'Month', 'Period', 'Indicator', 'Data Value',
#        'Percent Complete', 'Percent Pending Investigation', 'State Name',
#        'Footnote', 'Footnote Symbol', 'Predicted Value'],
#       dtype='object')

# %% [markdown]
# * State: state abbreviation
# * Year/Month: separated; need to be combined and converted to datetime; already aggregated by month
# * Period: 12 month period, same for all
# * Indicator: CDC's numerical codes for different drug types (summed in "Number of Drug Overdose Deaths")
# * Data Value: Number of overdoses (broken down by type of drug)
# * Percent Complete: jurisdictions reporting, same for all
# * Percent Pending Investigation: Deaths that are unconfirmed but suspected to be OD; negligible amount
# * Footnote', 'Footnote Symbol', 'Predicted Value': internal system? No meta data explaining this that I could find
#
#
# * Missing data - drug type was not specified for some states in 2015

# %%
od_df.sample(10)
# Out:
#       State  Year     Month           Period  \
# 22651    OH  2019  February  12 month-ending
# 801      AL  2015     March  12 month-ending
# 25706    SC  2017      July  12 month-ending
# 28504    US  2015  December  12 month-ending
# 4622     DC  2017  February  12 month-ending
# 8358     IA  2016  December  12 month-ending
# 17688    NC  2020     April  12 month-ending
# 18970    NJ  2015   January  12 month-ending
# 20331    NM  2019      July  12 month-ending
# 25640    SC  2017     April  12 month-ending
#
#                                                Indicator        Data Value  \
# 22651                                   Number of Deaths           122,776
# 801                       Number of Drug Overdose Deaths               733
# 25706                                    Cocaine (T40.5)               212
# 28504                       Percent with drugs specified  83.0777416718925
# 4622          Synthetic opioids, excl. methadone (T40.4)               176
# 8358   Natural & semi-synthetic opioids, incl. methad...                95
# 17688                        Opioids (T40.0-T40.4,T40.6)             1,777
# 18970           Natural & semi-synthetic opioids (T40.2)               NaN
# 20331  Natural, semi-synthetic, & synthetic opioids, ...               260
# 25640         Synthetic opioids, excl. methadone (T40.4)               273
#
#       Percent Complete  Percent Pending Investigation            State Name  \
# 22651              100                       0.015475                  Ohio
# 801                100                       0.308997               Alabama
# 25706              100                       0.046033        South Carolina
# 28504              100                       0.153227         United States
# 4622               100                       0.000000  District of Columbia
# 8358               100                       0.006822                  Iowa
# 17688              100                       0.783646        North Carolina
# 18970              100                       0.259162            New Jersey
# 20331              100                       0.177058            New Mexico
# 25640              100                       0.038043        South Carolina
#
#                                                 Footnote Footnote Symbol  \
# 22651              Underreported due to incomplete data.               *
# 801    Numbers may differ from published reports usin...              **
# 25706  Numbers may differ from published reports usin...              **
# 28504  Numbers may differ from published reports usin...              **
# 4622   Numbers may differ from published reports usin...              **
# 8358   Numbers may differ from published reports usin...              **
# 17688              Underreported due to incomplete data.               *
# 18970  Numbers may differ from published reports usin...              **
# 20331              Underreported due to incomplete data.               *
# 25640  Numbers may differ from published reports usin...              **
#
#       Predicted Value
# 22651             NaN
# 801               758
# 25706             214
# 28504             NaN
# 4622              176
# 8358               96
# 17688           1,956
# 18970             NaN
# 20331             266
# 25640             274

# %% [markdown]
# Steps:
#
# 1. Subset relevent columns
# 2. Filter out territories/cities
# 3. Put together Month/Year > convert to datetime
# 4. Filer relevent rows - only interested in opioids (which includes natural, semi-synthetic, synthetic opioids) and sums

# %% [markdown]
# Step 1: Subset columns

# %%
cols_to_use = ['State','Month','Year','Indicator','Data Value']
od_df = od_df[cols_to_use]
od_df
# Out:
#       State  Month  Year                                          Indicator  \
# 0        AK  April  2015                                     Heroin (T40.1)
# 1        AK  April  2015  Natural, semi-synthetic, & synthetic opioids, ...
# 2        AK  April  2015                                    Cocaine (T40.5)
# 3        AK  April  2015                                  Methadone (T40.3)
# 4        AK  April  2015      Psychostimulants with abuse potential (T43.6)
# ...     ...    ...   ...                                                ...
# 35485    YC    May  2020                                     Heroin (T40.1)
# 35486    YC    May  2020                                   Number of Deaths
# 35487    YC    May  2020           Natural & semi-synthetic opioids (T40.2)
# 35488    YC    May  2020                     Number of Drug Overdose Deaths
# 35489    YC    May  2020         Synthetic opioids, excl. methadone (T40.4)
#
#       Data Value
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 35485        688
# 35486     80,969
# 35487        337
# 35488      1,669
# 35489      1,168
#
# [35490 rows x 5 columns]

# %% [markdown]
# Step 2: filter out territories/cities

# %%
row_filter = od_df['State'].isin(['US', 'DC','YC'])
od_df = od_df[-row_filter]
states = od_df['State'].unique()
len(states)
# Out:
# 50

# %% [markdown]
# Step 3: Reformat to datetime

# %%
od_df = od_df.copy()
od_df['Date'] = pd.to_datetime(od_df['Year'].astype(str) + od_df['Month'], format = '%Y%B')
od_df = od_df.set_index(pd.to_datetime(od_df['Date']))
od_df
# Out:
#            State  Month  Year  \
# Date
# 2015-04-01    AK  April  2015
# 2015-04-01    AK  April  2015
# 2015-04-01    AK  April  2015
# 2015-04-01    AK  April  2015
# 2015-04-01    AK  April  2015
# ...          ...    ...   ...
# 2020-05-01    WY    May  2020
# 2020-05-01    WY    May  2020
# 2020-05-01    WY    May  2020
# 2020-05-01    WY    May  2020
# 2020-05-01    WY    May  2020
#
#                                                     Indicator Data Value  \
# Date
# 2015-04-01                                     Heroin (T40.1)        NaN
# 2015-04-01  Natural, semi-synthetic, & synthetic opioids, ...        NaN
# 2015-04-01                                    Cocaine (T40.5)        NaN
# 2015-04-01                                  Methadone (T40.3)        NaN
# 2015-04-01      Psychostimulants with abuse potential (T43.6)        NaN
# ...                                                       ...        ...
# 2020-05-01                                     Heroin (T40.1)        NaN
# 2020-05-01                                   Number of Deaths      4,808
# 2020-05-01           Natural & semi-synthetic opioids (T40.2)         28
# 2020-05-01                     Number of Drug Overdose Deaths         88
# 2020-05-01         Synthetic opioids, excl. methadone (T40.4)         23
#
#                  Date
# Date
# 2015-04-01 2015-04-01
# 2015-04-01 2015-04-01
# 2015-04-01 2015-04-01
# 2015-04-01 2015-04-01
# 2015-04-01 2015-04-01
# ...               ...
# 2020-05-01 2020-05-01
# 2020-05-01 2020-05-01
# 2020-05-01 2020-05-01
# 2020-05-01 2020-05-01
# 2020-05-01 2020-05-01
#
# [33150 rows x 6 columns]

# %%
od_df.shape
# Out:
# (33150, 6)

# %% [markdown]
# Step 4: Filter relavent rows

# %%
row_fitler = od_df['Indicator'].isin(['Opioids (T40.0-T40.4,T40.6)','Number of Drug Overdose Deaths','Number of Deaths'])
od_opioids_df = od_df[row_fitler]
od_opioids_df.head(10)
# Out:
#            State     Month  Year                       Indicator Data Value  \
# Date
# 2015-04-01    AK     April  2015                Number of Deaths      4,133
# 2015-04-01    AK     April  2015  Number of Drug Overdose Deaths        126
# 2015-04-01    AK     April  2015     Opioids (T40.0-T40.4,T40.6)        NaN
# 2015-08-01    AK    August  2015     Opioids (T40.0-T40.4,T40.6)        NaN
# 2015-08-01    AK    August  2015                Number of Deaths      4,222
# 2015-08-01    AK    August  2015  Number of Drug Overdose Deaths        124
# 2015-12-01    AK  December  2015     Opioids (T40.0-T40.4,T40.6)        NaN
# 2015-12-01    AK  December  2015  Number of Drug Overdose Deaths        121
# 2015-12-01    AK  December  2015                Number of Deaths      4,193
# 2015-02-01    AK  February  2015                Number of Deaths      4,084
#
#                  Date
# Date
# 2015-04-01 2015-04-01
# 2015-04-01 2015-04-01
# 2015-04-01 2015-04-01
# 2015-08-01 2015-08-01
# 2015-08-01 2015-08-01
# 2015-08-01 2015-08-01
# 2015-12-01 2015-12-01
# 2015-12-01 2015-12-01
# 2015-12-01 2015-12-01
# 2015-02-01 2015-02-01

# %%
od_df.shape, od_opioids_df.shape
# Out:
# ((33150, 6), (9100, 6))

# %%
od_opioids_df['State'].nunique()
# Out:
# 50

# %%
cols_to_use = ['State','Indicator','Data Value']
od_cleaned = od_opioids_df[cols_to_use]
od_cleaned
# Out:
#            State                       Indicator Data Value
# Date
# 2015-04-01    AK                Number of Deaths      4,133
# 2015-04-01    AK  Number of Drug Overdose Deaths        126
# 2015-04-01    AK     Opioids (T40.0-T40.4,T40.6)        NaN
# 2015-08-01    AK     Opioids (T40.0-T40.4,T40.6)        NaN
# 2015-08-01    AK                Number of Deaths      4,222
# ...          ...                             ...        ...
# 2020-03-01    WY  Number of Drug Overdose Deaths         81
# 2020-03-01    WY     Opioids (T40.0-T40.4,T40.6)         45
# 2020-05-01    WY     Opioids (T40.0-T40.4,T40.6)         51
# 2020-05-01    WY                Number of Deaths      4,808
# 2020-05-01    WY  Number of Drug Overdose Deaths         88
#
# [9100 rows x 3 columns]

# %% [markdown]
# Reformat:
# Its difficult to get totals for the three indicators I'm interested in, because they are all in rows - I want to have each of them in their own column.
# * Number of Deaths: the total number of deaths by any cause
# * Number of Drug OVerdose Deaths: the number of deaths where cause of death is overdose
# * Opioids: the number of fatal overdoses caused by opioids (as opposed to another drug type, ex. meth)

# %%
o_filter = od_cleaned['Indicator'].isin(['Opioids (T40.0-T40.4,T40.6)'])
opioid_df = od_cleaned[o_filter]
opioid_df['Data Value'] = opioid_df['Data Value'].str.replace(',', '').astype(float)
opioid_df = opioid_df.rename(columns={'Data Value': 'Opioid Deaths'})
del opioid_df['Indicator']
opioid_df['State'].nunique()
# Out:
# 40

# %%
nod_filter = od_cleaned['Indicator'].isin(['Number of Deaths'])
nod_df = od_cleaned[nod_filter]
nod_df['Data Value'] = nod_df['Data Value'].str.replace(',', '').astype(float)
nod_df = nod_df.rename(columns={'Data Value': 'Number of Deaths'})
del nod_df['Indicator']
nod_df['State'].nunique()
# Out:
# 50

# %%
nodod_filter = od_cleaned['Indicator'].isin(['Number of Drug Overdose Deaths'])
nodod_df = od_cleaned[nodod_filter]
nodod_df['Data Value'] = nodod_df['Data Value'].str.replace(',', '').astype(float)
nodod_df = nodod_df.rename(columns={'Data Value': 'Number of Drug Overdose Deaths'})
del nodod_df['Indicator']
nodod_df['State'].nunique()
# Out:
# 50

# %%
pd.merge?

# %%
merged1 = opioid_df.merge(nod_df, on=['Date', 'State'], how='outer')
merged_df = merged1.merge(nodod_df, on=['Date', 'State'], how='outer')
merged_df['State'].nunique()
# Out:
# 50

# %%
merged_df=merged_df.sort_values(['State', 'Date'])
merged_df
# Out:
#            State  Opioid Deaths  Number of Deaths  \
# Date
# 2015-01-01    AK            NaN            4034.0
# 2015-02-01    AK            NaN            4084.0
# 2015-03-01    AK            NaN            4101.0
# 2015-04-01    AK            NaN            4133.0
# 2015-05-01    AK            NaN            4196.0
# ...          ...            ...               ...
# 2020-01-01    WY           47.0            4748.0
# 2020-02-01    WY           46.0            4783.0
# 2020-03-01    WY           45.0            4757.0
# 2020-04-01    WY           46.0            4828.0
# 2020-05-01    WY           51.0            4808.0
#
#             Number of Drug Overdose Deaths
# Date
# 2015-01-01                           126.0
# 2015-02-01                           127.0
# 2015-03-01                           125.0
# 2015-04-01                           126.0
# 2015-05-01                           125.0
# ...                                    ...
# 2020-01-01                            78.0
# 2020-02-01                            80.0
# 2020-03-01                            81.0
# 2020-04-01                            83.0
# 2020-05-01                            88.0
#
# [3250 rows x 4 columns]

# %%
merged_df['State'].nunique()
# Out:
# 50

# %%
merged_df.reset_index(level=0,inplace=True)
merged_df
# Out:
#            Date State  Opioid Deaths  Number of Deaths  \
# 0    2015-01-01    AK            NaN            4034.0
# 1    2015-02-01    AK            NaN            4084.0
# 2    2015-03-01    AK            NaN            4101.0
# 3    2015-04-01    AK            NaN            4133.0
# 4    2015-05-01    AK            NaN            4196.0
# ...         ...   ...            ...               ...
# 3245 2020-01-01    WY           47.0            4748.0
# 3246 2020-02-01    WY           46.0            4783.0
# 3247 2020-03-01    WY           45.0            4757.0
# 3248 2020-04-01    WY           46.0            4828.0
# 3249 2020-05-01    WY           51.0            4808.0
#
#       Number of Drug Overdose Deaths
# 0                              126.0
# 1                              127.0
# 2                              125.0
# 3                              126.0
# 4                              125.0
# ...                              ...
# 3245                            78.0
# 3246                            80.0
# 3247                            81.0
# 3248                            83.0
# 3249                            88.0
#
# [3250 rows x 5 columns]

# %%
merged_df.to_csv('../data/od_data_longterm.csv',index=False)
